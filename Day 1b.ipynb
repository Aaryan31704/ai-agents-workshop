# %%
import os
from dotenv import load_dotenv

load_dotenv()

# Try to get API key from environment variable
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# If not found, you can set it directly here (uncomment and add your key):
# GOOGLE_API_KEY = "your-api-key-here"

if GOOGLE_API_KEY:
    print(f"API Setup complete - Key found")
   
else:
    print("Warning: GOOGLE_AI_API_KEY not set!")
    print("Please either:")
    print("  1. Set environment variable: GOOGLE_AI_API_KEY")
    print("  2. Or uncomment and set GOOGLE_API_KEY in this cell")
# Out:
# API Setup complete - Key found
# API Key: AIzaSyDAvulhsk8UazKCnlMVla1U2O3MZLVi-N8

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# # 2.1 RESEARCH AND SUMMARIZATION SYSTEM

# %%
# Research Agent
research_agent = Agent(
    name = "ResearchAgent",
    model = Gemini(
        model = "gemini-2.5-flash-lite",
        api_key = GOOGLE_API_KEY,
        retry_options = retry_config
    ),
    instruction = """You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools = [google_search],
    output_key="research_findings"
)
print("✅ Research Agent created successfully.")
# Out:
# ✅ Research Agent created successfully.

# %%
# Summarizer Agent

summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    
    instruction="""Read the provided research findings: {research_findings}. Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Agent - this basically orchestrates the research and summarization process

root_agent = Agent(
    name = "ReseachCoordinator",
    model = Gemini(
        model = "gemini-2.5-flash-lite",
        retry_options = retry_config,
        api_key = GOOGLE_API_KEY
    ),
    instruction = """You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
                1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
                2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
                3. Finally, present the final summary clearly to the user as your response.""",
    tools = [AgentTool(research_agent), AgentTool(summarizer_agent)]
)
print("✅ Root Agent created successfully.")
# Out:
# ✅ Root Agent created successfully.

# %%
runner = InMemoryRunner(agent = root_agent, app_name = "Research and Summarization System")
response = await runner.run_debug("What are the latest advancements in quantum computing and what do they mean for AI?")
# Out:
# App name mismatch detected. The runner is configured with app name "Research and Summarization System", but the root agent was loaded from "C:\Users\aarya\Desktop\Aaryan\Projects\Agents\ai-agents-workshop\agentenv\Lib\site-packages\google\adk\agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# App name mismatch detected. The runner is configured with app name "Research and Summarization System", but the root agent was loaded from "C:\Users\aarya\Desktop\Aaryan\Projects\Agents\ai-agents-workshop\agentenv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# App name mismatch detected. The runner is configured with app name "Research and Summarization System", but the root agent was loaded from "C:\Users\aarya\Desktop\Aaryan\Projects\Agents\ai-agents-workshop\agentenv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# ReseachCoordinator > The latest advancements in quantum computing are set to revolutionize AI by significantly enhancing its computational power, leading to faster, smarter, and more precise applications. This convergence, known as Quantum AI, promises to unlock new capabilities in areas such as personalized medicine and finance, while also offering a more energy-efficient and sustainable approach to AI computation. Researchers are making strides in quantum error correction, which is essential for building reliable quantum systems and is expected to lead to major breakthroughs in the coming decade.

# %% [markdown]
# # 2.2 Sequential Agents
# -> in the normal multi agent where LLM routes the query, when instruction becomes complex, the LLM might not route it in order
# -> so we use sequetial agents, we run the sub-agents in the order

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name = "BlogPipeline",
    sub_agents = [outline_agent, writer_agent, editor_agent],
)
print("✅ BlogPipeline created successfully.")
# Out:
# ✅ BlogPipeline created successfully.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\aarya\Desktop\Aaryan\Projects\Agents\ai-agents-workshop\agentenv\Lib\site-packages\google\adk\agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Blog Outline:
#
# **Headline:** Supercharge Your Software: Unleash the Power of Multi-Agent Systems
#
# **Introduction Hook:** Ever felt like your software projects are juggling too many tasks, making development a chaotic mess? What if there was a way to break down complexity, foster collaboration, and build more robust, adaptable applications? Enter multi-agent systems (MAS) – a revolutionary approach that's changing how developers think about and build software.
#
# **Main Sections:**
#
# **1. What Exactly Are Multi-Agent Systems? (The "Why" Behind the Buzz)**
#
# *   **Decomposition & Specialization:** Imagine your software not as a monolithic block, but as a team of specialized "agents," each with its own expertise and responsibilities. MAS allows you to break down complex problems into smaller, manageable sub-problems, assigning each to a dedicated agent.
# *   **Inter-Agent Communication & Coordination:** These agents don't work in isolation. They can communicate, negotiate, and collaborate to achieve a common goal, much like a well-oiled team. This intelligent interaction is the core of MAS.
# *   **Emergent Behavior & Problem Solving:** When individual agents interact, surprising and powerful "emergent behaviors" can arise, leading to more intelligent and adaptive solutions than any single agent could achieve alone.
#
# **2. The Developer's Toolkit: Key Benefits of Embracing MAS**
#
# *   **Enhanced Modularity & Maintainability:** By dividing your system into independent agents, changes to one agent have minimal impact on others, making your codebase cleaner, easier to understand, and significantly simpler to maintain and update.
# *   **Increased Robustness & Fault Tolerance:** If one agent fails, the system can often continue functioning, perhaps with degraded performance, thanks to the distributed nature and potential for redundancy offered by MAS. This resilience is a game-changer for critical applications.
# *   **Improved Scalability & Flexibility:** MAS naturally lend themselves to distributed architectures. You can easily add or remove agents as your needs change, allowing your software to scale efficiently and adapt to new requirements with greater agility.
#
# **3. Real-World Applications: Where MAS is Already Shines**
#
# *   **Complex Simulations & Modeling:** From traffic management to economic forecasting, MAS excel at simulating intricate environments with multiple interacting entities.
# *   **Robotics & Autonomous Systems:** Think self-driving cars or drone swarms – MAS are fundamental to enabling these systems to perceive, reason, and act autonomously in dynamic environments.
# *   **Smart Grids & Resource Management:** Optimizing energy distribution, managing resources efficiently, and responding to fluctuations are areas where MAS can orchestrate complex operations.
# *   **E-commerce & Personalized Recommendations:** Agents can work together to understand user preferences, find optimal products, and personalize the online shopping experience.
#
# **4. Getting Started: Your First Steps into the Agentic World**
#
# *   **Understanding Agent Architectures:** Explore different agent models like BDI (Belief-Desire-Intention) or reactive agents to understand how they process information and make decisions.
# *   **Leveraging MAS Frameworks:** Discover existing libraries and frameworks (e.g., JADE, SPADE, Mesa) that provide tools and structures to build your own multi-agent systems, saving you significant development time.
# *   **Start Small & Iterate:** Begin with a simple problem and a few agents. As you gain experience, gradually increase the complexity and number of agents in your system.
#
# **Concluding Thought:** Multi-agent systems aren't just a niche academic concept; they represent a powerful paradigm shift for software development. By embracing the principles of decentralization, specialization, and intelligent collaboration, developers can unlock new levels of complexity, robustness, and adaptability in their software, paving the way for more intelligent and efficient solutions to tomorrow's challenges.
# WriterAgent > ## Supercharge Your Software: Unleash the Power of Multi-Agent Systems
#
# Ever felt like your software projects are juggling too many tasks, making development a chaotic mess? What if there was a way to break down complexity, foster collaboration, and build more robust, adaptable applications? Enter multi-agent systems (MAS) – a revolutionary approach that's changing how developers think about and build software.
#
# At its core, MAS transforms your software from a monolithic entity into a team of specialized "agents." Imagine breaking down a large problem into smaller, manageable sub-problems, each handled by a dedicated agent with its own expertise. These agents don't work in isolation; they communicate, negotiate, and collaborate, much like a well-oiled team, to achieve a common goal. This intelligent interaction is where the magic happens, leading to emergent behaviors and more sophisticated problem-solving capabilities.
#
# For developers, embracing MAS offers a powerful toolkit. **Enhanced modularity and maintainability** become a reality. When your system is divided into independent agents, changes to one agent have minimal impact on others, leading to cleaner code that's easier to understand and update. Furthermore, MAS significantly boost **robustness and fault tolerance**. If one agent encounters an issue, the system can often continue functioning, a crucial advantage for critical applications. Finally, MAS naturally support **improved scalability and flexibility**, allowing you to effortlessly add or remove agents as your needs evolve, ensuring your software scales efficiently and adapts with agility.
#
# From complex simulations and autonomous systems to smart grids and personalized e-commerce experiences, MAS are already proving their worth across diverse industries. Ready to dive in? Start by exploring agent architectures and leveraging existing MAS frameworks. Begin with a simple problem and a few agents, and you'll soon unlock new levels of complexity, robustness, and adaptability in your software.
# EditorAgent > ## Supercharge Your Software: Unleash the Power of Multi-Agent Systems
#
# Ever felt like your software projects are juggling too many tasks, leading to a chaotic development process? What if there was a way to break down complexity, foster collaboration, and build more robust, adaptable applications? Enter multi-agent systems (MAS) – a revolutionary approach that's transforming how developers think about and build software.
#
# At its core, MAS reimagines your software not as a monolithic entity, but as a team of specialized "agents." Imagine decomposing a large, intricate problem into smaller, manageable sub-problems, with each one handled by a dedicated agent possessing its own unique expertise. Crucially, these agents don't operate in isolation. They communicate, negotiate, and collaborate, much like a well-oiled team, striving to achieve a common objective. This intelligent interaction is where the true magic of MAS lies, giving rise to emergent behaviors and sophisticated problem-solving capabilities.
#
# For developers, embracing MAS offers a powerful toolkit. You'll experience **enhanced modularity and maintainability**. By dividing your system into independent agents, modifications to one agent have minimal ripple effects on others. This results in cleaner code that's easier to understand, update, and manage. Furthermore, MAS significantly boosts **robustness and fault tolerance**. If one agent encounters an issue, the overall system can often continue functioning, a critical advantage for applications where downtime is unacceptable. Finally, MAS naturally support **improved scalability and flexibility**. You can effortlessly add or remove agents as your needs evolve, ensuring your software scales efficiently and adapts with agility to changing requirements.
#
# From complex simulations and autonomous systems to smart grids and personalized e-commerce experiences, MAS are already demonstrating their value across a diverse range of industries. Ready to dive in? Begin by exploring different agent architectures and leveraging existing MAS frameworks. Start with a simple problem and a small number of agents, and you'll soon unlock new levels of complexity, robustness, and adaptability in your software.

# %% [markdown]
# # 2.3 Parallel Multi-Topic Research system

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent 
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\aarya\Desktop\Aaryan\Projects\Agents\ai-agents-workshop\agentenv\Lib\site-packages\google\adk\agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > **Tech Trends:**
#
# *   **Generative AI Expansion:** Generative AI is moving beyond text to create diverse content like images, video, and music. Companies like OpenAI and Google are at the forefront, with its application expanding into marketing and creative workflows.
# *   **Agentic AI:** This involves autonomous AI agents that can independently plan and execute multi-step tasks, acting as "virtual coworkers." This is particularly useful for process automation.
# *   **AI Democratization & Low-Code/No-Code:** AI is becoming more accessible to non-experts through open-source solutions and user-friendly platforms, enabling wider adoption across industries.
#
# **Health Trends:**
#
# *   **Personalized Wellness & Longevity:** A shift towards proactive health, focusing on extending healthspan rather than just lifespan. This includes DNA-based testing, cellular health supplements, and sleep optimization tools.
# *   **Functional Foods & Supplements:** Increased interest in foods and supplements with specific health benefits, such as adaptogens, nootropics, and Lion's Mane mushroom, for gut health, cognitive function, and stress reduction.
# *   **Mental Wellness & Stress Management:** Growing focus on mental health solutions, including techniques like stimulating the vagus nerve, cold plunging for anxiety, and breathwork.
#
# **Finance Trends:**
#
# *   **AI Integration for Efficiency and Personalization:** AI is revolutionizing financial services by streamlining operations, enhancing customer personalization, and improving decision-making. The AI in finance market is projected for significant growth.
# *   **Embedded Finance:** Financial services are increasingly integrated into non-financial platforms, allowing for seamless transactions like buy-now-pay-later options within retail apps. This market is expected to see substantial growth.
# *   **Private Credit and Asset-Backed Finance:** Investment-grade private credit and asset-backed finance are gaining traction as institutional investors seek yield premiums and diversification.
# HealthResearcher > Here's a summary of recent breakthroughs in Tech, Health, and Finance:
#
# **Health:**
# *   **CRISPR Therapeutics:** Advancements in gene editing are leading to potential cures for genetic disorders, viral infections, and autoimmune diseases. Approvals like Casgevy mark a significant shift towards curative therapies. (Expected to continue development and approvals in the near future).
# *   **Gene Therapy for Hearing Loss:** A groundbreaking procedure has restored hearing in a deaf child by delivering functional OTOF genes to the inner ear. Further trials are anticipated.
# *   **GLP-1 Analogues for Cardiovascular Health:** Medications like semaglutide, initially for diabetes, are now approved to reduce heart attack and stroke risk and show promise for heart failure and arthritis.
#
# **Technology:**
# *   **Agentic AI:** This emerging AI trend involves autonomous digital agents that can plan and execute complex tasks with minimal human intervention, promising increased efficiency.
# *   **Quantum Computing:** While still facing scaling challenges, advancements like Google's Willow chip and Microsoft's quantum computer initiatives signal its growing practical applications in various fields.
# *   **5G Technology:** Continued rollout and development of 5G are enabling faster speeds and lower latency, crucial for advancements in IoT, smart cities, and remote procedures.
#
# **Finance:**
# *   **Embedded Finance:** Financial services are increasingly integrated into non-financial platforms, projected to reach $138 billion by 2026, offering seamless transactions.
# *   **AI-Powered Personalization:** AI is central to FinTech, with the AI market in financial services reaching $115.4 billion, driving personalized experiences and efficient operations.
# *   **Decentralized Finance (DeFi) Maturation:** DeFi protocols are improving in security, scalability, and regulatory alignment, offering more robust alternatives to traditional financial platforms.
# FinanceResearcher > **Fintech Trends:**
#
# 1.  **AI and ML Integration:** Financial institutions are increasingly adopting AI and ML for enhanced fraud detection, personalized customer service, and improved credit scoring. This trend is market-driving by creating more efficient and intuitive financial interactions. The future outlook points to AI becoming fundamental in reducing financial risks and tailoring services.
#
# 2.  **Emerging Payment Technologies:** Real-time payments, stablecoins, and pay-by-bank services are gaining mainstream adoption. The market implication is a shift away from traditional payment methods towards faster, more integrated digital solutions. The future will see these technologies becoming standard alternatives.
#
# 3.  **Embedded Finance:** The integration of financial services into non-financial platforms is a significant growth area. Market projections show substantial growth, driven by demand for seamless digital experiences and Banking-as-a-Service models. This trend is set to revolutionize how consumers access financial products.
#
# **Technology Trends:**
#
# 1.  **Democratization of AI:** AI is becoming more accessible, moving beyond large enterprises to smaller businesses, fueled by open-source solutions and lower costs. This democratizes access to powerful AI tools. The future holds widespread AI adoption across industries.
#
# 2.  **Rise of Autonomous Systems:** Robots and digital agents are evolving from pilot projects to practical applications, capable of learning and adapting. This trend is transforming automation across sectors like healthcare and manufacturing. The future will see these systems handling complex decision-making.
#
# 3.  **Expansion of IoT:** The number of global IoT connections is growing rapidly, with enterprise IoT markets poised for significant expansion. Advancements in 5G and chip manufacturing are accelerating this trend, improving connectivity and data collection for businesses.
#
# **Health Trends:**
#
# 1.  **Digital Health Solutions:** Telemedicine, mobile health apps, and wearables are surging in popularity, enhancing accessibility and real-time health monitoring. The market implication is a move towards more convenient and efficient healthcare delivery. The future will see increased AI-driven diagnostics and virtual consultations.
#
# 2.  **Focus on Digestive and Gut Health:** Consumers are prioritizing digestive health, driving growth in related supplements and food categories. This trend is expected to continue, influenced by factors like travel and new medical advancements.
#
# 3.  **Personalized and Preventive Healthcare:** There's a growing demand for customized treatments and proactive health measures like early disease detection. Companies investing in precision healthcare and preventive care will gain a competitive edge, shaping a future focused on individual wellness.
# AggregatorAgent > **Executive Briefing: Tech, Health, and Finance Trends**
#
# The convergence of Artificial Intelligence and personalized approaches is the dominant theme across technology, health, and finance. AI is rapidly expanding beyond text generation to encompass images, video, and autonomous agents capable of complex task execution, driving efficiency and personalization across industries. This AI democratization, fueled by accessible platforms, empowers broader adoption.
#
# In health, the focus is shifting to proactive, personalized wellness and longevity, utilizing tools from DNA testing to sleep optimization. This aligns with breakthroughs in gene editing (CRISPR) and gene therapy, offering potential cures for genetic disorders and even restoring hearing. Furthermore, GLP-1 analogues are demonstrating significant benefits beyond diabetes, including cardiovascular health.
#
# Financially, AI integration is revolutionizing services through enhanced personalization, fraud detection, and efficiency. Embedded finance, where financial services seamlessly integrate into non-financial platforms, is a major growth area, alongside emerging payment technologies like real-time payments and stablecoins. The maturation of DeFi also presents new, more robust financial alternatives.
#
# **Key Takeaways:**
#
# *   **AI as a Unifying Force:** AI is a pervasive driver of innovation and efficiency across all three sectors.
# *   **Personalization is Paramount:** From tailored financial products to individual wellness plans and gene-specific therapies, a hyper-personalized approach is key.
# *   **Proactive and Curative Solutions:** Both health and finance are moving towards proactive measures and advanced, curative solutions, indicating a future focused on prevention and long-term well-being and financial stability.

# %% [markdown]
# # 2.4 Loop Workflow

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# Exit loop
def exit_loop():
    return {"status":"aaproved", "message":"Exiting loop"}

print("✅ exit_loop function defined.")
# Out:
# ✅ exit_loop function defined.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\aarya\Desktop\Aaryan\Projects\Agents\ai-agents-workshop\agentenv\Lib\site-packages\google\adk\agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > The salt spray kissed Elias’s weathered face as he polished the Fresnel lens, the beacon his only companion on this desolate rock. Another night, another storm brewing. He’d seen his share of oddities out here – ghost ships, spectral lights – but nothing prepared him for the object that washed ashore with the morning tide. It was a rolled parchment, brittle with age, but the strangest thing was the faint, ethereal glow emanating from within.
#
# Unfurling it carefully, Elias gasped. It wasn’t paper, but some sort of treated hide, depicting constellations he’d never charted, oceans unlisted on any map. And across its surface, intricate lines of light pulsed, like veins carrying starlight. It was a map, yes, but to where? The glowing symbols seemed to shift, beckoning him toward the horizon, toward a mystery as vast and deep as the sea itself.
# CriticAgent > This is a promising start to a story, but it needs a bit more development to truly shine.
#
# Here are a few suggestions:
#
# 1.  **Deepen Elias's Character:** While we get a glimpse of Elias through "weathered face" and his experience with "oddities," we don't know much else about him. What drives him to this isolated life? Does he have any regrets, hopes, or fears beyond the immediate mystery? Adding a touch more personal detail would make the reader care more about his fate as he embarks on this unknown journey. For example, perhaps he's seeking something he lost, or running from something in his past.
#
# 2.  **Amplify the Mystery of the Map:** The description of the map is good, but you could make it even more intriguing. What kind of "oceans unlisted on any map"? Are there any recognizable elements within these unknown constellations or seas that might spark Elias's (or the reader's) curiosity or dread? Consider hinting at the *nature* of the map's destination – is it a place of wonder, danger, or something entirely alien? Perhaps a specific symbol briefly flashes into something Elias *almost* recognizes, creating a tantalizing, unfulfilled clue.
#
# 3.  **Introduce a Hint of Immediate Conflict or Decision:** The story ends with Elias contemplating the map. While this is a natural pause, adding a small element of immediate consequence or a looming decision could propel the narrative forward more effectively. For instance, the storm mentioned earlier could be intensifying, forcing Elias to make a quick choice about the map and his lighthouse duties. Or perhaps the map's glow intensifies, and he feels an overwhelming, almost irresistible urge to act *now*.
# RefinerAgent > The salt spray kissed Elias’s weathered face as he polished the Fresnel lens, the beacon his only companion on this desolate rock. He’d sought this solitude, a penance for a life lost at sea years ago, a life he’d drowned with his own reckless youth. Now, decades later, the only company he kept were the gulls and the ghosts of his past, spectral lights on the horizon his only nightly visitors. Another night, another storm brewing, the wind howling like a hungry wolf. He’d seen his share of oddities out here – ships with tattered sails manned by no one, eerie lights dancing on the waves – but nothing prepared him for the object that washed ashore with the morning tide. It was a rolled parchment, brittle with age, but the strangest thing was the faint, ethereal glow emanating from within, a captured piece of the aurora borealis.
#
# Unfurling it carefully, Elias gasped. It wasn’t paper, but some sort of treated hide, impossibly thin yet durable. It depicted constellations he’d never charted, alien star-patterns that sent a shiver down his spine, and oceans unlisted on any map, swirling with phosphorescent currents. And across its surface, intricate lines of light pulsed, like veins carrying starlight. It was a map, yes, but to where? One cluster of stars, a spiraling nebula of emerald light, seemed to pulse with a familiar rhythm, a fleeting image of his daughter’s locket flashing in his mind’s eye before dissolving. The glowing symbols shifted, beckoning him toward the horizon, toward a mystery as vast and deep as the sea itself.
#
# Suddenly, the storm, which had been a distant rumble, crashed against the lighthouse with renewed fury. The wind shrieked, rattling the very stones of his sanctuary, and the waves clawed at the base of the tower. The map in his hands pulsed brighter, a warm, insistent hum vibrating through his fingertips. It felt like a call, an undeniable summons. The sea had taken so much from him; perhaps, just perhaps, it was offering something back. The choice was stark: cling to the familiar solitude, his self-imposed penance, or follow the impossible path laid out by starlight, a path that might lead to answers, or to oblivion. The urge to step out into the tempest, to follow the map’s ethereal glow, was almost overwhelming.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
